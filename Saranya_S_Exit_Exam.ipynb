# %%
## Importing necessary Libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## Reading the dataset into the python environment

df = pd.read_csv('/content/Employee.csv')

# %% [markdown]
# ## Exploratory Data Analysis (EDA) & Preprocessing

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                   2.0
# 1              Poor             High                Low                   3.0
# 2              Good             High                Low                   0.0
# 3              Good             High               High                   1.0
# 4              Fair        Very High            Average                   0.0
#
# ...

# %%
df.tail()
# Out:
#        Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 74493        16243   56  Female                42  Healthcare            7830
# 74494        47175   30  Female                15   Education            3856
# 74495        12409   52    Male                 5   Education            5654
# 74496         9554   18    Male                 4   Education            5276
# 74497        73042   59  Female                48   Education            3774
#
#       Work-Life Balance Job Satisfaction Performance Rating  \
# 74493              Poor           Medium            Average
# 74494              Good           Medium            Average
# 74495              Good        Very High      Below Average
# 74496              Fair             High            Average
# 74497              Good             High      Below Average
#
#        Number of Promotions  ... Number of Dependents  Job Level Company Size  \
# ...

# %% [markdown]
# The first and last 5 rows of the data has shown above for a brief look on the dataset.
# For the further understanding, checking the info, summary and shape of the dataset.

# %%
df.shape
# Out:
# (74498, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74498 entries, 0 to 74497
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               74498 non-null  int64
#  1   Age                       74498 non-null  int64
#  2   Gender                    74498 non-null  object
#  3   Years at Company          74498 non-null  int64
#  4   Job Role                  74498 non-null  object
#  5   Monthly Income            74498 non-null  int64
#  6   Work-Life Balance         74494 non-null  object
#  7   Job Satisfaction          74498 non-null  object
#  8   Performance Rating        74494 non-null  object
#  9   Number of Promotions      74493 non-null  float64
#  10  Overtime                  74498 non-null  object
#  11  Distance from Home        74498 non-null  int64
#  12  Education Level           74493 non-null  object
# ...

# %%
df.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  74498.000000  74498.000000      74498.000000    74498.000000
# mean   37249.500000     38.529746         15.721603     7299.379514
# std    21505.864514     12.083456         11.223744     2152.508566
# min        1.000000     18.000000          1.000000     1226.000000
# 25%    18625.250000     28.000000          7.000000     5652.000000
# 50%    37249.500000     39.000000         13.000000     7348.000000
# 75%    55873.750000     49.000000         23.000000     8876.000000
# max    74498.000000     59.000000         51.000000    16149.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          74493.000000        74498.000000          74492.000000
# mean               0.832978           49.991584              1.650365
# std                0.995303           28.513611              1.553660
# min                0.000000            1.000000              0.000000
# ...

# %%
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %%
cats= ['Gender','Job Role','Job Satisfaction','Marital Status','Company Size','Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
       'Company Reputation', 'Employee Recognition']
ordinal = ['Work-Life Balance', 'Job Satisfaction','Performance Rating','Education Level','Job Level']
binary = ['Attrition']
nums = df.loc[:, ~df.columns.isin(cats + binary + ordinal)].columns[1:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-3078976c4f78> in <cell line: 5>()
#       3 ordinal = ['Work-Life Balance', 'Job Satisfaction','Performance Rating','Education Level','Job Level']
#       4 binary = ['Attrition']
# ----> 5 nums = df.loc[:, ~df.columns.isin(cats + binary + ordinal)].columns[1:]
#
# AttributeError: 'numpy.int64' object has no attribute 'loc'

# %%
# Example DataFrame creation
data = {
    'Employee ID': [1, 2, 3, 4, 5],
    'Age': [30, 35, 40, 45, 50],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
    'Years at Company': [5, 10, 3, 8, 2],
    'Job Role': ['Manager', 'Engineer', 'Administrator', 'Manager', 'Engineer'],
    'Monthly Income': [6000, 7000, 5000, 8000, 5500],
    'Work-Life Balance': ['Good', 'Excellent', 'Fair', 'Good', 'Excellent'],
    'Job Satisfaction': ['High', 'Medium', 'Low', 'High', 'Medium'],
    'Performance Rating': ['High', 'Medium', 'Low', 'High', 'Medium'],
    'Number of Promotions': [1, 2, 0, 3, 1],
    'Overtime': ['Yes', 'No', 'Yes', 'Yes', 'No'],
    'Distance from Home': [10, 5, 15, 20, 8],
    'Education Level': ['Bachelor', 'Master', 'High School', 'Ph.D.', 'Bachelor'],
    'Marital Status': ['Married', 'Single', 'Married', 'Divorced', 'Single'],
    'Number of Dependents': [2, 0, 1, 3, 1],
    'Job Level': ['Entry-level', 'Manager', 'Entry-level', 'Senior Manager', 'Manager'],
    'Company Size': ['Large', 'Medium', 'Small', 'Large', 'Medium'],
    'Company Tenure': [5, 10, 3, 8, 2],
    'Remote Work': ['Yes', 'No', 'Yes', 'Yes', 'No'],
    'Leadership Opportunities': ['Yes', 'No', 'Yes', 'No', 'Yes'],
    'Innovation Opportunities': ['Yes', 'No', 'No', 'Yes', 'Yes'],
    'Company Reputation': ['Good', 'Excellent', 'Poor', 'Good', 'Excellent'],
    'Employee Recognition': ['Yes', 'No', 'No', 'Yes', 'No'],
    'Attrition': ['No', 'Yes', 'No', 'No', 'Yes']
}

df = pd.DataFrame(data)

# Define categorical, binary, and ordinal columns
cats = ['Gender', 'Job Role', 'Work-Life Balance', 'Job Satisfaction', 'Performance Rating',
        'Education Level', 'Marital Status', 'Job Level', 'Company Size', 'Remote Work',
        'Leadership Opportunities', 'Innovation Opportunities', 'Company Reputation',
        'Employee Recognition', 'Attrition']

binary = ['Attrition']  # Assuming Attrition is binary, though it can be considered categorical too

ordinal = ['Work-Life Balance', 'Job Satisfaction', 'Performance Rating', 'Education Level',
           'Job Level', 'Company Size']

# Select numeric columns that are not in cats, binary, or ordinal
nums = df.loc[:, ~df.columns.isin(cats + binary + ordinal)].columns.tolist()

print(nums)
# Out:
# ['Employee ID', 'Age', 'Years at Company', 'Monthly Income', 'Number of Promotions', 'Overtime', 'Distance from Home', 'Number of Dependents', 'Company Tenure']

# %%
df= df.isna().sum()
df
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %% [markdown]
# it shows there is no null values , null values are zero.

# %%
df.dtype
# Out:
# dtype('int64')

# %%
def summary(text, df):
    print(f'{text} shape: {df.shape}')

    # Initialize a summary DataFrame
    summ = pd.DataFrame(df.dtypes, columns=['dtypes'])
    summ['null'] = df.isnull().sum()
    summ['unique'] = df.nunique()
    summ['min'] = df.min()

# %%
def calculate_numeric_summary(df):
    # Select only numeric columns
    numeric_df = df.select_dtypes(include=['number'])

    # Calculate summary statistics
    summ = pd.DataFrame({
        'median': numeric_df.median(),
        'mean': numeric_df.mean(),
        'std': numeric_df.std(),
        'max': numeric_df.max()
    })

    return summ

# %%
# Select numeric columns that are not in cats, binary, or ordinal
nums = df.loc[:, ~df.columns.isin(cats + binary + ordinal)].columns.tolist()

plt.figure(figsize=(12,4))
for i in range(0, len(nums)):
    plt.subplot(2, 5, i+1)
    sns.boxplot(y=df[nums[i]], color='chocolate')
    plt.tight_layout()

# %% [markdown]
# There are no outliers detected from this box plot representation

# %%
## Checking correlation matrix

# %%
corr = df.select_dtypes(include=['int64',])

# %%
corr = df.select_dtypes(include=['int64', 'float64']).corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# from this correlation matrix we can see there are a few strong positive correlation between the variables such as number of promotions, monthly income, years at company etc are showing more than 75 % correlation.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Attrition'] = df['Attrition'].replace(['No', 'Yes'], [0, 1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Attrition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df = pd.get_dummies(df)
df
# Out:
#    Employee ID  Age  Years at Company  Monthly Income  Number of Promotions  \
# 0            1   30                 5            6000                     1
# 1            2   35                10            7000                     2
# 2            3   40                 3            5000                     0
# 3            4   45                 8            8000                     3
# 4            5   50                 2            5500                     1
#
#    Distance from Home  Number of Dependents  Company Tenure  Gender_Female  \
# 0                  10                     2               5          False
# 1                   5                     0              10           True
# 2                  15                     1               3          False
# 3                  20                     3               8           True
# 4                   8                     1               2          False
#
#    Gender_Male  ...  Leadership Opportunities_Yes  \
# ...

# %% [markdown]
# ##Train Test Split

# %%
X = df.drop('Attrition')
y=df('Attrition')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-efb3fcf8b212> in <cell line: 1>()
# ----> 1 X = df.drop('Attrition')
#       2 y=df('Attrition')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.25)

# %% [markdown]
# ## Modelling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,precision_score, recall_score,f1_score

# %%
## Logistic Regression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Making predictions
y_pred = log_reg.predict(X_test)

#calculating Confusion matrix, Accuracy,precision, recall,and f1 scores
print("accuracy is:", accuracy_score(y_test,y_pred))
print("Precision is:", precision_score(y_test,y_pred))
print("Recall is:", recall_score(y_test,y_pred))
print("f1 is:", f1_score(y_test,y_pred))
print("Confusion matrix is:", confusion_matrix(y_test,y_pred))

# %%
## Random Forest

rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)

# Making predictions
y_pred = log_reg.predict(X_test)

#calculating Confusion matrix, Accuracy,precision, recall,and f1 scores
print("accuracy is:", accuracy_score(y_test,y_pred))
print("Precision is:", precision_score(y_test,y_pred))
print("Recall is:", recall_score(y_test,y_pred))
print("f1 is:", f1_score(y_test,y_pred))
print("Confusion matrix is:", confusion_matrix(y_test,y_pred))

# %%
## Decision Tree

dt_classifier = RandomForestClassifier()
dt_classifier.fit(X_train, y_train)

# Making predictions
y_pred = log_reg.predict(X_test)

#calculating Confusion matrix, Accuracy,precision, recall,and f1 scores
print("accuracy is:", accuracy_score(y_test,y_pred))
print("Precision is:", precision_score(y_test,y_pred))
print("Recall is:", recall_score(y_test,y_pred))
print("f1 is:", f1_score(y_test,y_pred))
print("Confusion matrix is:", confusion_matrix(y_test,y_pred))
